# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f144c9bf-f1bf-4d19-b2b9-988ec94d392c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f144c9bf-f1bf-4d19-b2b9-988ec94d392c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv
# Saving train.csv to train.csv
# User uploaded file "test.csv" with length 2331766 bytes
# User uploaded file "train.csv" with length 4794242 bytes

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
print('Processing text dataset')
from nltk.tokenize import WordPunctTokenizer
from collections import Counter
from string import punctuation, ascii_lowercase
import regex as re
from tqdm import tqdm
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
# setup tokenizer

vocab = Counter()

def text_to_wordlist(text, lower=False):
  text = tokenizer.tokenize(text)
  text = [w for w in text if len(w) != 1]
  vocab.update(text)
  return text

def process_comments(list_sentences, lower=False):
    comments = []
    for text in tqdm(list_sentences):
        txt = text_to_wordlist(text, lower=lower)
        comments.append(txt)

    return comments

list_sentences_train = list(train_df["abstract"].fillna("NAN_WORD").values)
list_sentences_test = list(test_df["abstract"].fillna("NAN_WORD").values)

#Todas las keywords
comments = process_comments(list_sentences_train + list_sentences_test, lower=True)
# Out:
#  20%|██        | 1105/5417 [00:00<00:00, 10949.01it/s]
# Processing text dataset
# 100%|██████████| 5417/5417 [00:00<00:00, 12037.53it/s]

# %%
from gensim.models import Word2Vec


model = Word2Vec(comments, size=300, window=5, min_count=5, workers=16, sg=1)

# %%
word_vectors = model.wv
print("Number of word vectors: {}".format(len(word_vectors.vocab)))
# Out:
# Number of word vectors: 11043

# %%
#Definimos el tamaño de los vectores. Al estar trabajando con keywords podemos escoger un tamaño que no sea muy grane
MAX_NB_WORDS = len(word_vectors.vocab)
MAX_SEQUENCE_LENGTH = 30

from keras.preprocessing.sequence import pad_sequences

#Diccionario con todas las palabras asignadas un i + 1. 
word_index = {t[0]: i+1 for i,t in enumerate(vocab.most_common(MAX_NB_WORDS))}

#Para cada una de las palabras de los articulos le damos su valor de word_index (en el caso de TRAIN)
sequences = [[word_index.get(t, 0) for t in comment]
             for comment in comments[:len(list_sentences_train)]]

#Para cada una de las palabras de los articulos le damos su valor de word_index (en el caso de TEST)
test_sequences = [[word_index.get(t, 0)  for t in comment] 
                  for comment in comments[len(list_sentences_train):]]

# Mediante la funcion pad_sequences recortamos los vectores de keywords a una longitud determinada, en este caso 20. 
#Ajuste del tamaño para TRAIN
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
list_classes = ["Cardio", "Diges", "Resp", "Nerv", "Infe"]
y = train_df[list_classes].values
print('Shape de los tensores training (data):', data.shape)
print('Shape de los tensores label del training (y):', y.shape)

#Ajuste del tamaño para TEST
test_data = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding="post",
                          truncating="post")
print('Shape de los tensores del test (test_data):', test_data.shape)
# Out:
# Shape de los tensores training (data): (3629, 30)
# Shape de los tensores label del training (y): (3629, 5)
# Shape de los tensores del test (test_data): (1788, 30)

# %%
# Preparacion de la embedding matrix

WV_DIM = 300
nb_words = min(MAX_NB_WORDS, len(word_vectors.vocab))

# we initialize the matrix with random numbers
wv_matrix = (np.random.rand(nb_words, WV_DIM) - 0.5) / 5.0

#hacemos la embedding matrix con los vectores del word2vec
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    try:
        embedding_vector = word_vectors[word]
        # words not found in embedding index will be all-zeros.
        wv_matrix[i] = embedding_vector
    except:
        pass

# %%
from keras.models import Sequential
from keras.layers import Dense, Input, LSTM, Embedding, Dropout,SpatialDropout1D, Bidirectional
from keras.models import Model
from keras.optimizers import Adam
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras import layers
from keras.layers import Dense, Embedding, Dropout, SpatialDropout1D
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, Conv1D, GRU, LSTM, BatchNormalization
from keras.layers import  GlobalMaxPool1D, SpatialDropout1D
from keras.layers import Bidirectional
from keras.models import Model
from keras import optimizers

# Embedding layer for text inputs
input_words = Input((MAX_SEQUENCE_LENGTH, ))
x_words = Embedding(nb_words,
                     WV_DIM,
                     mask_zero=False,
                     weights=[wv_matrix],
                     input_length=MAX_SEQUENCE_LENGTH,
                     trainable=False)(input_words)

x_words = SpatialDropout1D(0.1)(x_words)
x_words = LSTM(128, return_sequences=True)(x_words)
x_words = Dropout(0.1)(x_words)
x_words = Conv1D(64, 2, activation='relu', )(x_words)
x_words = GlobalMaxPool1D()(x_words)
x_words = Dropout(0.1)(x_words)

x = Dense(32, activation="relu")(x_words)
x = Dropout(0.1)(x)
preds = Dense(5, activation="softmax")(x)

model_2 = Model(inputs=[input_words], outputs=preds)
model_2.compile(loss='mae',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 30)]              0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 30, 300)           1074000
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 30, 300)           0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 30, 256)           439296
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30, 256)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 29, 128)           65664
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 1,585,665
# Trainable params: 511,665
# Non-trainable params: 1,074,000
# _________________________________________________________________

# %%
LSTMCNN_abstract_word2vec = model_2.fit([data], y, validation_split=0.1,
                 epochs=30, batch_size=150, shuffle=True)
# Out:
# Epoch 1/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.1148 - accuracy: 0.7174 - val_loss: 0.1231 - val_accuracy: 0.6860
# Epoch 2/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1144 - accuracy: 0.7186 - val_loss: 0.1318 - val_accuracy: 0.6639
# Epoch 3/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.1123 - accuracy: 0.7250 - val_loss: 0.1178 - val_accuracy: 0.7135
# Epoch 4/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1113 - accuracy: 0.7263 - val_loss: 0.1212 - val_accuracy: 0.6942
# Epoch 5/30
# 22/22 [==============================] - 3s 147ms/step - loss: 0.1104 - accuracy: 0.7281 - val_loss: 0.1165 - val_accuracy: 0.7080
# Epoch 6/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.1098 - accuracy: 0.7303 - val_loss: 0.1257 - val_accuracy: 0.6887
# Epoch 7/30
# 22/22 [==============================] - 3s 159ms/step - loss: 0.1091 - accuracy: 0.7309 - val_loss: 0.1213 - val_accuracy: 0.7025
# Epoch 8/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1086 - accuracy: 0.7318 - val_loss: 0.1252 - val_accuracy: 0.6832
# Epoch 9/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.1086 - accuracy: 0.7336 - val_loss: 0.1231 - val_accuracy: 0.6997
# Epoch 10/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1058 - accuracy: 0.7410 - val_loss: 0.1227 - val_accuracy: 0.6915
# Epoch 11/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1064 - accuracy: 0.7370 - val_loss: 0.1216 - val_accuracy: 0.6942
# Epoch 12/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1052 - accuracy: 0.7422 - val_loss: 0.1229 - val_accuracy: 0.6942
# Epoch 13/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1036 - accuracy: 0.7449 - val_loss: 0.1207 - val_accuracy: 0.6997
# Epoch 14/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1037 - accuracy: 0.7431 - val_loss: 0.1209 - val_accuracy: 0.7052
# Epoch 15/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.1028 - accuracy: 0.7489 - val_loss: 0.1226 - val_accuracy: 0.6915
# Epoch 16/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1049 - accuracy: 0.7404 - val_loss: 0.1239 - val_accuracy: 0.6860
# Epoch 17/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1029 - accuracy: 0.7453 - val_loss: 0.1220 - val_accuracy: 0.6970
# Epoch 18/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.1027 - accuracy: 0.7462 - val_loss: 0.1236 - val_accuracy: 0.6915
# Epoch 19/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0989 - accuracy: 0.7554 - val_loss: 0.1212 - val_accuracy: 0.6970
# Epoch 20/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.1013 - accuracy: 0.7502 - val_loss: 0.1214 - val_accuracy: 0.6970
# Epoch 21/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0987 - accuracy: 0.7544 - val_loss: 0.1233 - val_accuracy: 0.6942
# Epoch 22/30
# 22/22 [==============================] - 3s 148ms/step - loss: 0.0991 - accuracy: 0.7541 - val_loss: 0.1231 - val_accuracy: 0.6970
# Epoch 23/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.0981 - accuracy: 0.7578 - val_loss: 0.1209 - val_accuracy: 0.6970
# Epoch 24/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.0969 - accuracy: 0.7621 - val_loss: 0.1230 - val_accuracy: 0.6832
# Epoch 25/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.0955 - accuracy: 0.7633 - val_loss: 0.1245 - val_accuracy: 0.6860
# Epoch 26/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0975 - accuracy: 0.7603 - val_loss: 0.1212 - val_accuracy: 0.6942
# Epoch 27/30
# 22/22 [==============================] - 3s 149ms/step - loss: 0.0967 - accuracy: 0.7627 - val_loss: 0.1207 - val_accuracy: 0.6970
# Epoch 28/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.0946 - accuracy: 0.7661 - val_loss: 0.1272 - val_accuracy: 0.6749
# Epoch 29/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.0988 - accuracy: 0.7551 - val_loss: 0.1214 - val_accuracy: 0.6970
# Epoch 30/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.0960 - accuracy: 0.7636 - val_loss: 0.1231 - val_accuracy: 0.6942

# %%
train_loss = np.mean(word2vec_ads.history['loss'])
val_loss = np.mean(word2vec_ads.history['val_loss'])
print('Train loss: %f' % (train_loss*100))
print('Validation loss: %f' % (val_loss*100))
# Out:
# Train loss: 16.414037
# Validation loss: 15.327026

# %%
history = pd.DataFrame(LSTMCNN_abstract_word2vec.history)
plt.figure(figsize=(6,3));
plt.plot(history["loss"], 'bo', label='training data'); #puntos
plt.plot(history["val_loss"], 'b', label='validation data'); #linea
plt.title("LSTM+CNN loss with Word2vec (abstract)");
plt.legend(bbox_to_anchor=(0.9, 0.9))
plt.show();

# %%
history = pd.DataFrame(LSTMCNN_abstract_word2vec.history)
plt.figure(figsize=(6,3));
plt.plot(history["accuracy"], 'bo', label='training data'); #puntos
plt.plot(history["val_accuracy"], 'b', label='validation data'); #linea
plt.title("LSTM+CNN accuracy with Word2vec (abstract)");
plt.legend(bbox_to_anchor=(0.9, 0.3))
plt.show();
