# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f144c9bf-f1bf-4d19-b2b9-988ec94d392c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f144c9bf-f1bf-4d19-b2b9-988ec94d392c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv
# Saving train.csv to train.csv
# User uploaded file "test.csv" with length 2331766 bytes
# User uploaded file "train.csv" with length 4794242 bytes

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
print('Processing text dataset')
from nltk.tokenize import WordPunctTokenizer
from collections import Counter
from string import punctuation, ascii_lowercase
import regex as re
from tqdm import tqdm
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
# setup tokenizer

vocab = Counter()

def text_to_wordlist(text, lower=False):
  text = tokenizer.tokenize(text)
  text = [w for w in text if len(w) != 1]
  vocab.update(text)
  return text

def process_comments(list_sentences, lower=False):
    comments = []
    for text in tqdm(list_sentences):
        txt = text_to_wordlist(text, lower=lower)
        comments.append(txt)

    return comments

list_sentences_train = list(train_df["keywords"].fillna("NAN_WORD").values)
list_sentences_test = list(test_df["keywords"].fillna("NAN_WORD").values)

#Todas las keywords
comments = process_comments(list_sentences_train + list_sentences_test, lower=True)
# Out:
# 100%|██████████| 5417/5417 [00:00<00:00, 51697.88it/s]
# Processing text dataset

# %%
# !pip install glove_python
# Out:
# Collecting glove_python
#   Downloading https://files.pythonhosted.org/packages/3e/79/7e7e548dd9dcb741935d031117f4bed133276c2a047aadad42f1552d1771/glove_python-0.1.0.tar.gz (263kB)
#      |████████████████████████████████| 266kB 8.3MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from glove_python) (1.19.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from glove_python) (1.4.1)
# Building wheels for collected packages: glove-python
#   Building wheel for glove-python (setup.py) ... done
#   Created wheel for glove-python: filename=glove_python-0.1.0-cp36-cp36m-linux_x86_64.whl size=700292 sha256=e372bbbed438badf2c80168ed2f5e9331d2ada81c8decb02b635e86f39bf8e06
#   Stored in directory: /root/.cache/pip/wheels/88/4b/6d/10c0d2ad32c9d9d68beec9694a6f0b6e83ab1662a90a089a4b
# Successfully built glove-python
# Installing collected packages: glove-python
# Successfully installed glove-python-0.1.0

# %%
import glove
from glove import Glove, Corpus

corpus = Corpus()
corpus.fit(comments, window=5)

model = Glove(no_components=100, learning_rate=0.05)
model.fit(corpus.matrix, epochs=30, no_threads=16, verbose=True)
# Out:
# Performing 30 training epochs with 16 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20
# Epoch 21
# Epoch 22
# Epoch 23
# Epoch 24
# Epoch 25
# Epoch 26
# Epoch 27
# Epoch 28
# Epoch 29

# %%
word_vectors = model.word_vectors
print("Number of word vectors: {}".format(len(word_vectors)))
# Out:
# Number of word vectors: 13638

# %%
#Definimos el tamaño de los vectores. Al estar trabajando con keywords podemos escoger un tamaño que no sea muy grane
MAX_NB_WORDS = len(word_vectors)
MAX_SEQUENCE_LENGTH = 30

from keras.preprocessing.sequence import pad_sequences

#Diccionario con todas las palabras asignadas un i + 1. 
word_index = {t[0]: i+1 for i,t in enumerate(vocab.most_common(MAX_NB_WORDS))}

#Para cada una de las palabras de los articulos le damos su valor de word_index (en el caso de TRAIN)
sequences = [[word_index.get(t, 0) for t in comment]
             for comment in comments[:len(list_sentences_train)]]

#Para cada una de las palabras de los articulos le damos su valor de word_index (en el caso de TEST)
test_sequences = [[word_index.get(t, 0)  for t in comment] 
                  for comment in comments[len(list_sentences_train):]]

# Mediante la funcion pad_sequences recortamos los vectores de keywords a una longitud determinada, en este caso 20. 
#Ajuste del tamaño para TRAIN
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH, 
                     padding="pre", truncating="post")
list_classes = ["Cardio", "Diges", "Resp", "Nerv", "Infe"]
y = train_df[list_classes].values
print('Shape de los tensores training (data):', data.shape)
print('Shape de los tensores label del training (y):', y.shape)

#Ajuste del tamaño para TEST
test_data = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding="post",
                          truncating="post")
print('Shape de los tensores del test (test_data):', test_data.shape)
# Out:
# Shape de los tensores training (data): (3629, 30)
# Shape de los tensores label del training (y): (3629, 5)
# Shape de los tensores del test (test_data): (1788, 30)

# %%
# Preparacion de la embedding matrix

WV_DIM = 300
nb_words = min(MAX_NB_WORDS, len(word_vectors))

# we initialize the matrix with random numbers
wv_matrix = (np.random.rand(nb_words, WV_DIM) - 0.5) / 5.0

#hacemos la embedding matrix con los vectores del word2vec
for word, i in word_index.items():
    if i >= MAX_NB_WORDS:
        continue
    try:
        embedding_vector = word_vectors[word]
        # words not found in embedding index will be all-zeros.
        wv_matrix[i] = embedding_vector
    except:
        pass

# %%
from keras.models import Sequential
from keras.layers import Dense, Input, LSTM, Embedding, Dropout,SpatialDropout1D, Bidirectional
from keras.models import Model
from keras.optimizers import Adam
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras import layers
from keras.layers import Dense, Embedding, Dropout, SpatialDropout1D
from keras.callbacks import EarlyStopping
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, Conv1D, GRU, LSTM, BatchNormalization
from keras.layers import  GlobalMaxPool1D, SpatialDropout1D
from keras.layers import Bidirectional
from keras.models import Model
from keras import optimizers

# Embedding layer for text inputs
input_words = Input((MAX_SEQUENCE_LENGTH, ))
x_words = Embedding(nb_words,
                     WV_DIM,
                     mask_zero=False,
                     weights=[wv_matrix],
                     input_length=MAX_SEQUENCE_LENGTH,
                     trainable=False)(input_words)

x_words = SpatialDropout1D(0.1)(x_words)
x_words = LSTM(128, return_sequences=True)(x_words)
x_words = Dropout(0.1)(x_words)
x_words = Conv1D(64, 2, activation='relu', )(x_words)
x_words = GlobalMaxPool1D()(x_words)
x_words = Dropout(0.1)(x_words)

x = Dense(32, activation="relu")(x_words)
x = Dropout(0.1)(x)
preds = Dense(5, activation="softmax")(x)

model_2 = Model(inputs=[input_words], outputs=preds)
model_2.compile(loss='mae',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 30)]              0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 30, 300)           1074000
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, 30, 300)           0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 30, 256)           439296
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30, 256)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 29, 128)           65664
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 1,585,665
# Trainable params: 511,665
# Non-trainable params: 1,074,000
# _________________________________________________________________

# %%
LSTMCNN_keywords_Glove = model_2.fit([data], y, validation_split=0.1,
                 epochs=30, batch_size=150, shuffle=True)
# Out:
# Epoch 1/30
# 22/22 [==============================] - 6s 172ms/step - loss: 0.3161 - accuracy: 0.2195 - val_loss: 0.2997 - val_accuracy: 0.2672
# Epoch 2/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.3036 - accuracy: 0.2498 - val_loss: 0.2903 - val_accuracy: 0.2727
# Epoch 3/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.2983 - accuracy: 0.2553 - val_loss: 0.2879 - val_accuracy: 0.2755
# Epoch 4/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.2973 - accuracy: 0.2541 - val_loss: 0.2931 - val_accuracy: 0.2645
# Epoch 5/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.2965 - accuracy: 0.2606 - val_loss: 0.2841 - val_accuracy: 0.3003
# Epoch 6/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.2868 - accuracy: 0.2975 - val_loss: 0.2759 - val_accuracy: 0.3196
# Epoch 7/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.2748 - accuracy: 0.3145 - val_loss: 0.2657 - val_accuracy: 0.3361
# Epoch 8/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.2888 - accuracy: 0.2886 - val_loss: 0.2670 - val_accuracy: 0.3333
# Epoch 9/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.2704 - accuracy: 0.3317 - val_loss: 0.2784 - val_accuracy: 0.3030
# Epoch 10/30
# 22/22 [==============================] - 3s 150ms/step - loss: 0.2611 - accuracy: 0.3556 - val_loss: 0.2565 - val_accuracy: 0.3636
# Epoch 11/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.2429 - accuracy: 0.4074 - val_loss: 0.2309 - val_accuracy: 0.4408
# Epoch 12/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.2301 - accuracy: 0.4343 - val_loss: 0.2325 - val_accuracy: 0.4353
# Epoch 13/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.2315 - accuracy: 0.4344 - val_loss: 0.2221 - val_accuracy: 0.4573
# Epoch 14/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.2136 - accuracy: 0.4789 - val_loss: 0.2357 - val_accuracy: 0.4187
# Epoch 15/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.2124 - accuracy: 0.4781 - val_loss: 0.2211 - val_accuracy: 0.4545
# Epoch 16/30
# 22/22 [==============================] - 3s 153ms/step - loss: 0.2035 - accuracy: 0.5011 - val_loss: 0.2151 - val_accuracy: 0.4656
# Epoch 17/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.2019 - accuracy: 0.5000 - val_loss: 0.2087 - val_accuracy: 0.4876
# Epoch 18/30
# 22/22 [==============================] - 3s 155ms/step - loss: 0.1980 - accuracy: 0.5115 - val_loss: 0.2081 - val_accuracy: 0.4821
# Epoch 19/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.1936 - accuracy: 0.5204 - val_loss: 0.2090 - val_accuracy: 0.4738
# Epoch 20/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1974 - accuracy: 0.5118 - val_loss: 0.2105 - val_accuracy: 0.4904
# Epoch 21/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.1871 - accuracy: 0.5421 - val_loss: 0.2128 - val_accuracy: 0.4711
# Epoch 22/30
# 22/22 [==============================] - 4s 163ms/step - loss: 0.1838 - accuracy: 0.5460 - val_loss: 0.1960 - val_accuracy: 0.5041
# Epoch 23/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.1789 - accuracy: 0.5531 - val_loss: 0.1881 - val_accuracy: 0.5262
# Epoch 24/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.1737 - accuracy: 0.5718 - val_loss: 0.1917 - val_accuracy: 0.5069
# Epoch 25/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.1738 - accuracy: 0.5690 - val_loss: 0.1874 - val_accuracy: 0.5317
# Epoch 26/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.1733 - accuracy: 0.5735 - val_loss: 0.1863 - val_accuracy: 0.5372
# Epoch 27/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.1721 - accuracy: 0.5790 - val_loss: 0.1870 - val_accuracy: 0.5344
# Epoch 28/30
# 22/22 [==============================] - 3s 151ms/step - loss: 0.1593 - accuracy: 0.6194 - val_loss: 0.1840 - val_accuracy: 0.5620
# Epoch 29/30
# 22/22 [==============================] - 3s 152ms/step - loss: 0.1642 - accuracy: 0.6099 - val_loss: 0.1748 - val_accuracy: 0.5675
# Epoch 30/30
# 22/22 [==============================] - 3s 154ms/step - loss: 0.1567 - accuracy: 0.6270 - val_loss: 0.1821 - val_accuracy: 0.5427

# %%
train_loss = np.mean(word2vec_ads.history['loss'])
val_loss = np.mean(word2vec_ads.history['val_loss'])
print('Train loss: %f' % (train_loss*100))
print('Validation loss: %f' % (val_loss*100))
# Out:
# Train loss: 16.414037
# Validation loss: 15.327026

# %%
history = pd.DataFrame(LSTMCNN_keywords_Glove.history)
plt.figure(figsize=(6,3));
plt.plot(history["loss"], 'bo', label='training data'); #puntos
plt.plot(history["val_loss"], 'b', label='validation data'); #linea
plt.title("LSTM+CNN loss with Glove (keywords)");
plt.legend(bbox_to_anchor=(0.9, 0.9))
plt.show();

# %%
history = pd.DataFrame(LSTMCNN_keywords_Glove.history)
plt.figure(figsize=(6,3));
plt.plot(history["accuracy"], 'bo', label='training data'); #puntos
plt.plot(history["val_accuracy"], 'b', label='validation data'); #linea
plt.title("LSTM+CNN accuracy with Glove (keywords)");
plt.legend(bbox_to_anchor=(0.9, 0.3))
plt.show();
